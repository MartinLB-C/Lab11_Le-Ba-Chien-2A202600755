# %% [markdown]
# # Lab 11 - Alibaba DashScope Guardrails & HITL
#
# Notebook này dùng code Python trong `src/` và chạy với Alibaba Cloud Model Studio / DashScope. Điền `DASHSCOPE_API_KEY` trong file `.env` ở thư mục gốc trước khi chạy với API thật. Nếu chưa có key, code dùng local fallback responses.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

print(f"Project root: {ROOT}")

# %%
from core.config import setup_api_key, get_alibaba_model

setup_api_key()
print("Alibaba model:", get_alibaba_model())

# %% [markdown]
# ## Part 1 - Attack unprotected agent

# %%
from main import part1_attacks

await part1_attacks()

# %% [markdown]
# ## Part 2 - Guardrails

# %%
from main import part2_guardrails

await part2_guardrails()

# %% [markdown]
# ## Part 3 - Testing pipeline

# %%
from main import part3_testing

await part3_testing()

# %% [markdown]
# ## Part 4 - HITL

# %%
from main import part4_hitl

part4_hitl()
