# %% [markdown]
# # Alibaba Attack / Defense Arena
#
# Notebook này chạy attack và guardrail comparison bằng Alibaba DashScope code trong `src/`. Nếu `DASHSCOPE_API_KEY` chưa được điền trong `.env`, notebook dùng local fallback responses.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

print(f"Project root: {ROOT}")

# %%
from core.config import setup_api_key, get_alibaba_model

setup_api_key()
print("Alibaba model:", get_alibaba_model())

# %% [markdown]
# ## Manual attack run

# %%
from agents.agent import create_unsafe_agent
from attacks.attacks import run_attacks

agent, runner = create_unsafe_agent()
attack_results = await run_attacks(agent, runner)

# %% [markdown]
# ## Before / after comparison

# %%
from testing.testing import run_comparison, print_comparison

unprotected, protected = await run_comparison()
print_comparison(unprotected, protected)
